# %% [markdown]
# # FIN 4000 — Chapter 11: The Efficient Market Hypothesis
# *Can you beat the market? Weak, semi-strong, and strong-form efficiency*
#
# **ANSWER KEY — fully worked, instructor reference**
#
# This notebook is the Python companion to the Chapter 11 Excel template — same data, same formulas, same numbers. Where the Excel workshop has you build a formula in a cell, this notebook has you build it in a line of Python instead.

# %% [markdown]
# ## Step 1 — Entry Quiz *(3 minutes, individually)*
#
# 1. What's the difference between weak-form and semi-strong-form market efficiency?
# 2. If markets are semi-strong-form efficient, why doesn't analyzing public financial statements earn abnormal returns?
# 3. What's an “anomaly,” and why do anomalies challenge the EMH?

# %% [markdown]
# ---

# %%
import numpy as np

# %% [markdown]
# ## Step 2 — Worked Example *(10 minutes, instructor-led)*
#
# A stock's actual return on the day of an earnings announcement was 3%. Based on its beta (1.2) and the market's return that day (1%), estimate the stock's ABNORMAL return using the market model.

# %%
actual1, beta1, r_m = 0.03, 1.2, 0.01

# %%
expected1 = beta1 * r_m
abnormal1 = actual1 - expected1
print(f'Expected={expected1:.2%}  Abnormal={abnormal1:.2%}')
# Out:
# Expected=1.20%  Abnormal=1.80%

# %% [markdown]
# *Expected return = 1.2×1% = 1.2%. Abnormal return = 3%−1.2% = 1.8%. This 1.8% likely reflects the market's reaction to the earnings news itself — new information the market model doesn't already capture.*

# %% [markdown]
# ## Step 3 — Pair Work *(12 minutes, with a partner)*

# %% [markdown]
# **1.** A second stock has beta 0.8 and also announced earnings the same day, with an actual return of 0.5%. Compute its abnormal return.

# %%
actual2, beta2 = 0.005, 0.8
expected2 = beta2 * r_m
abnormal2 = actual2 - expected2
print(f'Abnormal return={abnormal2:.2%}')
# Out:
# Abnormal return=-0.30%

# %% [markdown]
# **2.** If semi-strong EMH holds, how quickly should the full abnormal return show up in the stock price after the announcement — and what would it mean if the stock kept drifting upward for weeks afterward?

# %% [markdown]
# *(Conceptual — discuss with your partner.)*

# %% [markdown]
# **3.** Name one real anomaly (e.g., the value effect, size effect, or post-earnings-announcement drift) and explain why it's a challenge for the EMH.

# %% [markdown]
# *(Conceptual — discuss with your partner.)*

# %% [markdown]
# ## Step 4 — Python Pass *(7 minutes)*
#
# - The abnormal-return formula, built from actual-return/beta/market-return cells so any announcement day can be tested
# - Both stocks' abnormal returns computed side by side
# - A running (cumulative) abnormal return over several days, to see whether the reaction is a one-day jump or a slow drift

# %%
daily_returns = np.array([0.03, 0.01, 0.005, -0.002, 0.001])   # days 0-4 after announcement
daily_market  = np.array([0.01, 0.00, 0.002,  0.001, 0.000])
daily_abnormal = daily_returns - beta1 * daily_market
car = np.cumsum(daily_abnormal)
print('Cumulative abnormal return by day:', np.round(car, 4))
print('Flat after day 0 -> supports EMH. Still climbing -> argues against it.')
# Out:
# Cumulative abnormal return by day: [0.018  0.028  0.0306 0.0274 0.0284]
# Flat after day 0 -> supports EMH. Still climbing -> argues against it.

# %% [markdown]
# ## Step 5 — Discussion *(3-5 minutes, no calculation)*
#
# > If the market is efficient, why do so many professional fund managers still try to pick stocks instead of just buying an index fund? Is this necessarily irrational?
