# %% [markdown]
# # FIN 4000 — Chapter 17: Macroeconomic and Industry Analysis
# *Top-down investing — from the business cycle to industry selection*
#
# **ANSWER KEY — fully worked, instructor reference**
#
# This notebook is the Python companion to the Chapter 17 Excel template — same data, same formulas, same numbers. Where the Excel workshop has you build a formula in a cell, this notebook has you build it in a line of Python instead.

# %% [markdown]
# ## Step 1 — Entry Quiz *(3 minutes, individually)*
#
# 1. What's the difference between a cyclical industry and a defensive industry, and how does each tend to perform in a recession?
# 2. Name two macroeconomic indicators an analyst would watch to gauge where the economy is in the business cycle.
# 3. What does “industry life cycle” mean, and what stage would you expect a brand-new technology sector to be in?

# %% [markdown]
# ---

# %%
import numpy as np

# %% [markdown]
# ## Step 2 — Worked Example *(10 minutes, instructor-led)*
#
# An industry's sales historically grow 1.8× as fast as GDP growth (its “GDP elasticity” is 1.8). Forecast the industry's sales growth in an expansion (GDP +3%) and a recession (GDP −2%).

# %%
elasticity_cyclical = 1.8
gdp_expansion, gdp_recession = 0.03, -0.02

# %%
sales_exp = elasticity_cyclical * gdp_expansion
sales_rec = elasticity_cyclical * gdp_recession
print(f'Expansion={sales_exp:.2%}  Recession={sales_rec:.2%}')
# Out:
# Expansion=5.40%  Recession=-3.60%

# %% [markdown]
# *Expansion: 1.8×3%=5.4% sales growth. Recession: 1.8×(−2%)=−3.6% (an actual sales decline). An elasticity above 1.0 means this industry amplifies the business cycle — it's cyclical, not defensive.*

# %% [markdown]
# ## Step 3 — Pair Work *(12 minutes, with a partner)*

# %% [markdown]
# **1.** A defensive industry (e.g., utilities) has a GDP elasticity of 0.4. Forecast its sales growth in both the expansion and recession scenarios. Compare the swing to the cyclical industry's.

# %%
elasticity_defensive = 0.4
sales_exp_def = elasticity_defensive * gdp_expansion
sales_rec_def = elasticity_defensive * gdp_recession
print(f'Defensive: Expansion={sales_exp_def:.2%}  Recession={sales_rec_def:.2%}')
# Out:
# Defensive: Expansion=1.20%  Recession=-0.80%

# %% [markdown]
# **2.** Which industry would you rather own heading into a forecast recession, and why?

# %% [markdown]
# *(Conceptual — discuss with your partner.)*

# %% [markdown]
# **3.** Name a real industry you'd expect to have a GDP elasticity well above 1.0, and one you'd expect well below 1.0.

# %% [markdown]
# *(Conceptual — discuss with your partner.)*

# %% [markdown]
# ## Step 4 — Python Pass *(7 minutes)*
#
# - The elasticity-based sales forecast, built from elasticity/GDP-growth cells so any industry or scenario can be tested
# - Both industries (cyclical and defensive) forecast side by side across both scenarios
# - A quick swing calculation: expansion forecast minus recession forecast, to quantify each industry's cyclicality in one number

# %%
swing_cyclical = sales_exp - sales_rec
swing_defensive = sales_exp_def - sales_rec_def
print(f'Cyclical swing={swing_cyclical:.2%}   Defensive swing={swing_defensive:.2%}')
# Out:
# Cyclical swing=9.00%   Defensive swing=2.00%

# %% [markdown]
# ## Step 5 — Discussion *(3-5 minutes, no calculation)*
#
# > If you correctly forecast that the economy is about to enter a recession, does that automatically tell you which stocks to buy or sell? What else would you need to know?
