# %% [markdown]
# # FIN 4000 — Chapter 18: Equity Valuation Models
# *What is a share of stock actually worth? Dividend discount models and relative valuation*
#
# **ANSWER KEY — fully worked, instructor reference**
#
# This notebook is the Python companion to the Chapter 18 Excel template — same data, same formulas, same numbers. Where the Excel workshop has you build a formula in a cell, this notebook has you build it in a line of Python instead.

# %% [markdown]
# ## Step 1 — Entry Quiz *(3 minutes, individually)*
#
# 1. In the constant-growth (Gordon growth) dividend discount model, what happens to the formula as the growth rate g gets close to the required return r?
# 2. What's the difference between a stock's intrinsic value and its market price, and what should you do if intrinsic value > market price?
# 3. Name one equity valuation approach other than the dividend discount model.

# %% [markdown]
# ---

# %%
import numpy as np

# %% [markdown]
# ## Step 2 — Worked Example *(10 minutes, instructor-led)*
#
# A stock just paid a $2.00 dividend, expected to grow at 5% forever. Investors require an 11% return. Find the stock's intrinsic value using the constant-growth DDM.

# %%
D0, g, r = 2.00, 0.05, 0.11

# %%
D1 = D0 * (1 + g)
V0 = D1 / (r - g)
print(f'D1=${D1:.2f}  V0=${V0:.2f}')
# Out:
# D1=$2.10  V0=$35.00

# %% [markdown]
# *D₁ = $2.00×1.05 = $2.10. V₀ = $2.10 ÷ (0.11−0.05) = $2.10 ÷ 0.06 = $35.00.*

# %% [markdown]
# ## Step 3 — Pair Work *(12 minutes, with a partner)*

# %% [markdown]
# **1.** The stock currently trades at $30. Is it overvalued or undervalued according to your DDM estimate? What should an investor do?

# %%
market_price = 30
verdict = 'undervalued' if V0 > market_price else 'overvalued'
print(f'V0=${V0:.2f} vs price=${market_price} -> {verdict}')
# Out:
# V0=$35.00 vs price=$30 -> undervalued

# %% [markdown]
# **2.** If the growth rate rises to 7% instead of 5% (same r=11%), recompute the intrinsic value. How sensitive is the value to the growth assumption?

# %%
g_new = 0.07
V0_new = (D0 * (1 + g_new)) / (r - g_new)
print(f'V0 at g=7% = ${V0_new:.2f}  (vs ${V0:.2f} at g=5%)')
# Out:
# V0 at g=7% = $53.50  (vs $35.00 at g=5%)

# %% [markdown]
# **3.** What happens to the formula (and the implied value) as g rises all the way to 11%, equal to r? Why does this reveal a limitation of the constant-growth model?

# %% [markdown]
# *(Try g very close to 11% below and see what happens.)*

# %% [markdown]
# ## Step 4 — Python Pass *(7 minutes)*
#
# - The constant-growth DDM formula, built from D₀/g/r cells so any stock can be tested
# - A quick sensitivity table: intrinsic value recomputed for g = 3%, 5%, 7%, 9%
# - A comparison cell: intrinsic value vs. the current market price, with a simple over/undervalued flag

# %%
g_values = np.array([0.03, 0.05, 0.07, 0.09])
V0_values = (D0 * (1 + g_values)) / (r - g_values)
for g_i, v in zip(g_values, V0_values):
    print(f'g={g_i:.0%}:  V0 = ${v:.2f}')
# Out:
# g=3%:  V0 = $25.75
# g=5%:  V0 = $35.00
# g=7%:  V0 = $53.50
# g=9%:  V0 = $109.00

# %% [markdown]
# ## Step 5 — Discussion *(3-5 minutes, no calculation)*
#
# > Two analysts use the same dividend discount model and the same current dividend, but arrive at very different valuations for the same stock. What's the most likely reason, given how sensitive this model is?
